# %% [markdown]
# # Code for collocations in newspapers

# %% [markdown]
# Some startup code, make sure to activate

# %%
import dhlab.module_update as mu
mu.update('dhlab_v2', silent = True)
import dhlab_v2 as d2

import pandas as pd

# %%
mu.css("css.css")
# Out:
# <style>p {
#     font-size:1.2em;
#     color : #223355;
# }
# h1, h2, h3, h4, h5, h6 {
#     color:#3344aa;
# }
# html {
#     margin-left:10%;
#     margin-right:5%;
# }
#
# body {
#     counter-reset: h2counter;
# }
# h1 {
#     counter-reset: h2counter;
# }
# h2:before {
#     content: counter(h2counter) ".\0000a0\0000a0";
#     counter-increment: h2counter;
#     counter-reset: h3counter;
# }
# h3:before {
#     content: counter(h2counter) "." counter(h3counter) ".\0000a0\0000a0";
#     counter-increment: h3counter;
# }
# </style>

# %%
from random import sample

# %%
def sampling(a, b):
    res = a
    if b < len(a):
        res = sample(a, b)
    return res

# %%
def sort(df, col = None, up = True):
    if col is None:
        col = df.columns[0]
    return df.sort_values(by = col, ascending = (up == False))

# %%
def check_words(df, word_parts):
    """ do a df.loc[] on matches for word_parts - a kindof regex search through matches"""
    return pd.concat([df.loc[i] for i in [df[a].index for a in [df.index.str.contains(w) for w in word_parts]]])

# %% [markdown]
# # Setting things up
# Set up the data for analysis, totals and a collocation function

# %%
tot = d2.totals(200000)

# %% [markdown]
# With collocations, the information association is computed using PMI (pointwise mutual information), with probabilites as proportions of frequency, it takes the form: $pmi(x,y) = \frac{p(x|y)}{p(x)} = \frac{p(y|x)}{p(y)}$. It is a probabilistic version of relevance. That $y$ is relevant for $x$ and vice versa. PMI is used instead of $\text{tf-idf}$ for computing associations between words.
#
# The PMI-values are computed on normalized frequencies, which means that the actual number can be interpreted as a disproportion number.

# %%
def collocation(word, before = 20, after = 20, corpus = None, samples = 500000, totals = tot ):
    """ Collocations from counts - no distance here"""
    coll = d2.urn_collocation(urns = sampling(list(corpus.urn), samples), word = word, before = before, after = after)
    combo = pd.concat([coll, totals], axis = 1)
    combo.freq = combo.freq.fillna(min(combo.freq))
    combo.counts = combo.counts.fillna(min(combo.counts))
    combo['pmi'] = (combo.counts/combo.counts.sum())**1.02/(combo.freq/combo.freq.sum())
    return combo

# %% [markdown]
# ## Build a corpus
#
# The target corpus consists of newspapers published in Norway between 2020 and 2021

# %%
corpus = d2.document_corpus(doctype = 'digavis', from_year = 2020, to_year = 2021, limit = 100000)

# %% [markdown]
# Check how many documents there are in the corpus

# %%
len(corpus)
# Out:
# 43490

# %% [markdown]
# Substitute the red string below with any substring describing a newspaper, to see how many are included

# %%
len(corpus[corpus.urn.str.contains('vestnytt')])
# Out:
# 138

# %%
d2.concordance(urns = list(corpus.urn), words = """ "av korona"  """).apply(make_link).sample(5).style
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-24dfe10aaeca> in <module>
# ----> 1 d2.concordance(urns = list(corpus.urn), words = """ "av korona"  """).apply(make_link).sample(5).style
#
# NameError: name 'make_link' is not defined

# %%
concs = d2.concordance(urns = list(corpus.urn), words = """ sykkelritt korona  """)

# %%
concs.sample(min(5, len(concs))).style
# Out:
# <style  type="text/css" >
# </style><table id="T_c9e10_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9e10_level0_row0" class="row_heading level0 row0" >25</th>
#                         <td id="T_c9e10_row0_col0" class="data row0 col0" >203313043</td>
#                         <td id="T_c9e10_row0_col1" class="data row0 col1" >URN:NBN:no-nb_digavis_gjengangeren_null_null_20210421_0_0_1</td>
#                         <td id="T_c9e10_row0_col2" class="data row0 col2" >... La Flèche Wallonne , kvinner <b>Sykkelritt</b> . Direkte . 12.35 Proffjentene ( r ) 12.55 UEFA – Ett år med <b>korona</b> ( r ) 14.00 Sykkel : Endagsritt : La Flèche Wallonne... </td>
#             </tr>
#             <tr>
#                         <th id="T_c9e10_level0_row1" class="row_heading level0 row1" >14</th>
#                         <td id="T_c9e10_row1_col0" class="data row1 col0" >202879367</td>
#                         <td id="T_c9e10_row1_col1" class="data row1 col1" >URN:NBN:no-nb_digavis_vestnytt_null_null_20201103_33_83_1</td>
#                         <td id="T_c9e10_row1_col2" class="data row1 col2" >... Bilen kjem mellom anna til å bli brukt under leiteaksjonar og arrangement slik som <b>sykkelritt</b> . No i <b>korona</b>-tida har den gamle Røde Kors-bilen... </td>
#             </tr>
#             <tr>
#                         <th id="T_c9e10_level0_row2" class="row_heading level0 row2" >23</th>
#                         <td id="T_c9e10_row2_col0" class="data row2 col0" >203322943</td>
#                         <td id="T_c9e10_row2_col1" class="data row2 col1" >URN:NBN:no-nb_digavis_helgelendingen_null_null_20210421_91_59_1</td>
#                         <td id="T_c9e10_row2_col2" class="data row2 col2" >... La Flèche Wallonne , kvinner <b>Sykkelritt</b> . Direkte . 12.35 Proffjentene ( r ) 12.55 UEFA – Ett år med <b>korona</b> ( r ) 14.00 Sykkel : Endagsritt : La Flèche Wallonne... </td>
#             </tr>
#             <tr>
#                         <th id="T_c9e10_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c9e10_row3_col0" class="data row3 col0" >203368924</td>
#                         <td id="T_c9e10_row3_col1" class="data row3 col1" >URN:NBN:no-nb_digavis_ostlandetsblad_null_null_20210421_114_75_1</td>
#                         <td id="T_c9e10_row3_col2" class="data row3 col2" >... La Flèche Wallonne , kvinner <b>Sykkelritt</b> . Direkte . 12.35 Proffjentene ( r ) 12.55 UEFA – Ett år med <b>korona</b> ( r ) 14.00 Sykkel : Endagsritt : La Flèche Wallonne... </td>
#             </tr>
#             <tr>
#                         <th id="T_c9e10_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c9e10_row4_col0" class="data row4 col0" >202498786</td>
#                         <td id="T_c9e10_row4_col1" class="data row4 col1" >URN:NBN:no-nb_digavis_lindesnes_null_null_20200811_132_94_1</td>
#                         <td id="T_c9e10_row4_col2" class="data row4 col2" >... Tour of Norway for kids har holdt på siden 2005 og de arrangerer <b>sykkelritt</b> for barn i hele Norge . – Vi er innom femti steder i... </td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Collocations
#
# Try out different words to get a feel of things

# %%
def coll_dist(word, window = 10, corpus = None):
    before = collocation(word = word,before = window, after = 0, corpus = corpus)
    after = collocation(word = word,before = 0, after = window, corpus = corpus)
    before.columns = pd.MultiIndex.from_tuples([('before', x) for x in before.columns], names = ["place", "kind"])
    after.columns = pd.MultiIndex.from_tuples([('after', x) for x in after.columns], names = ["place", "kind"])
    result = pd.concat([before, after], axis = 1)
    return result

# %%
dcoll = coll_dist('korona', corpus = corpus, window = 20)

# %%
from math import log, sqrt, exp

# %%
dcoll[('before','score')] = (dcoll[('before','counts')].apply(log))*(dcoll[('before','bdist')]**-1)

# %%
dcoll[('after','score')] = (dcoll[('after','counts')].apply(log))*(dcoll[('after','bdist')]**-1)

# %%
dcoll[dcoll[('before', 'bdist') ] < 5].sort_values(by = ('before', 'counts'), ascending = True).head(50).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_d1e6f_row0_col0,#T_d1e6f_row0_col10,#T_d1e6f_row0_col11,#T_d1e6f_row1_col0,#T_d1e6f_row1_col1,#T_d1e6f_row1_col3,#T_d1e6f_row2_col3,#T_d1e6f_row3_col5,#T_d1e6f_row3_col6,#T_d1e6f_row3_col12,#T_d1e6f_row5_col3,#T_d1e6f_row5_col8,#T_d1e6f_row6_col3,#T_d1e6f_row6_col5,#T_d1e6f_row6_col12,#T_d1e6f_row7_col1,#T_d1e6f_row8_col3,#T_d1e6f_row9_col3,#T_d1e6f_row9_col5,#T_d1e6f_row9_col12,#T_d1e6f_row10_col3,#T_d1e6f_row12_col3,#T_d1e6f_row13_col3,#T_d1e6f_row13_col5,#T_d1e6f_row13_col12,#T_d1e6f_row15_col3,#T_d1e6f_row15_col8,#T_d1e6f_row16_col7,#T_d1e6f_row17_col5,#T_d1e6f_row18_col3,#T_d1e6f_row18_col8,#T_d1e6f_row19_col3,#T_d1e6f_row19_col5,#T_d1e6f_row19_col8,#T_d1e6f_row22_col3,#T_d1e6f_row22_col5,#T_d1e6f_row22_col12,#T_d1e6f_row23_col3,#T_d1e6f_row23_col5,#T_d1e6f_row23_col8,#T_d1e6f_row24_col3,#T_d1e6f_row24_col8,#T_d1e6f_row25_col3,#T_d1e6f_row25_col5,#T_d1e6f_row25_col6,#T_d1e6f_row25_col8,#T_d1e6f_row25_col12,#T_d1e6f_row26_col5,#T_d1e6f_row26_col9,#T_d1e6f_row27_col3,#T_d1e6f_row27_col8,#T_d1e6f_row30_col3,#T_d1e6f_row30_col8,#T_d1e6f_row33_col3,#T_d1e6f_row34_col3,#T_d1e6f_row40_col3,#T_d1e6f_row40_col5,#T_d1e6f_row40_col8,#T_d1e6f_row41_col2,#T_d1e6f_row41_col3,#T_d1e6f_row41_col6,#T_d1e6f_row44_col3,#T_d1e6f_row44_col8,#T_d1e6f_row46_col4,#T_d1e6f_row46_col9,#T_d1e6f_row47_col4,#T_d1e6f_row47_col9{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d1e6f_row0_col1,#T_d1e6f_row2_col1,#T_d1e6f_row5_col1,#T_d1e6f_row6_col1,#T_d1e6f_row9_col10,#T_d1e6f_row9_col11,#T_d1e6f_row16_col3,#T_d1e6f_row16_col8,#T_d1e6f_row22_col6,#T_d1e6f_row29_col3,#T_d1e6f_row29_col8,#T_d1e6f_row43_col3,#T_d1e6f_row43_col8,#T_d1e6f_row45_col4{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_d1e6f_row0_col2{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_d1e6f_row0_col3,#T_d1e6f_row0_col8,#T_d1e6f_row3_col9,#T_d1e6f_row4_col3,#T_d1e6f_row4_col8,#T_d1e6f_row7_col4,#T_d1e6f_row16_col4,#T_d1e6f_row17_col3,#T_d1e6f_row17_col8,#T_d1e6f_row28_col3,#T_d1e6f_row28_col8,#T_d1e6f_row31_col3,#T_d1e6f_row31_col8,#T_d1e6f_row35_col3,#T_d1e6f_row35_col8,#T_d1e6f_row37_col3,#T_d1e6f_row37_col8{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_d1e6f_row0_col4,#T_d1e6f_row0_col9,#T_d1e6f_row8_col10,#T_d1e6f_row8_col11,#T_d1e6f_row11_col4,#T_d1e6f_row21_col4,#T_d1e6f_row32_col3,#T_d1e6f_row32_col8,#T_d1e6f_row32_col9,#T_d1e6f_row40_col9{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_d1e6f_row0_col5,#T_d1e6f_row4_col4,#T_d1e6f_row5_col5,#T_d1e6f_row7_col9,#T_d1e6f_row11_col5,#T_d1e6f_row18_col5,#T_d1e6f_row20_col3,#T_d1e6f_row20_col8,#T_d1e6f_row27_col5,#T_d1e6f_row34_col5,#T_d1e6f_row41_col5,#T_d1e6f_row49_col9{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_d1e6f_row0_col6,#T_d1e6f_row3_col10,#T_d1e6f_row3_col11,#T_d1e6f_row4_col10,#T_d1e6f_row4_col11,#T_d1e6f_row10_col10,#T_d1e6f_row10_col11,#T_d1e6f_row17_col4,#T_d1e6f_row18_col6,#T_d1e6f_row19_col9,#T_d1e6f_row21_col9,#T_d1e6f_row27_col6,#T_d1e6f_row48_col3,#T_d1e6f_row48_col8{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_d1e6f_row0_col7,#T_d1e6f_row18_col7,#T_d1e6f_row27_col7{
#             background-color:  #157ab5;
#             color:  #000000;
#         }#T_d1e6f_row0_col12,#T_d1e6f_row2_col10,#T_d1e6f_row2_col11,#T_d1e6f_row5_col10,#T_d1e6f_row5_col11,#T_d1e6f_row6_col10,#T_d1e6f_row6_col11,#T_d1e6f_row13_col0,#T_d1e6f_row14_col0,#T_d1e6f_row15_col4,#T_d1e6f_row18_col12,#T_d1e6f_row27_col12,#T_d1e6f_row37_col9,#T_d1e6f_row49_col4{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_d1e6f_row1_col2,#T_d1e6f_row13_col10,#T_d1e6f_row13_col11,#T_d1e6f_row30_col6{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_d1e6f_row1_col4,#T_d1e6f_row30_col12{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_d1e6f_row1_col5,#T_d1e6f_row1_col6,#T_d1e6f_row1_col7,#T_d1e6f_row1_col8,#T_d1e6f_row1_col9,#T_d1e6f_row1_col12,#T_d1e6f_row2_col5,#T_d1e6f_row2_col6,#T_d1e6f_row2_col7,#T_d1e6f_row2_col8,#T_d1e6f_row2_col9,#T_d1e6f_row2_col12,#T_d1e6f_row6_col8,#T_d1e6f_row6_col9,#T_d1e6f_row8_col8,#T_d1e6f_row8_col9,#T_d1e6f_row9_col8,#T_d1e6f_row9_col9,#T_d1e6f_row10_col5,#T_d1e6f_row10_col6,#T_d1e6f_row10_col7,#T_d1e6f_row10_col8,#T_d1e6f_row10_col9,#T_d1e6f_row10_col12,#T_d1e6f_row12_col5,#T_d1e6f_row12_col6,#T_d1e6f_row12_col7,#T_d1e6f_row12_col8,#T_d1e6f_row12_col9,#T_d1e6f_row12_col12,#T_d1e6f_row13_col8,#T_d1e6f_row13_col9,#T_d1e6f_row17_col6,#T_d1e6f_row17_col7,#T_d1e6f_row17_col12,#T_d1e6f_row19_col6,#T_d1e6f_row19_col7,#T_d1e6f_row19_col12,#T_d1e6f_row22_col8,#T_d1e6f_row22_col9,#T_d1e6f_row23_col6,#T_d1e6f_row23_col7,#T_d1e6f_row23_col12,#T_d1e6f_row26_col6,#T_d1e6f_row26_col7,#T_d1e6f_row26_col12,#T_d1e6f_row33_col8,#T_d1e6f_row33_col9,#T_d1e6f_row34_col8,#T_d1e6f_row34_col9,#T_d1e6f_row40_col6,#T_d1e6f_row40_col7,#T_d1e6f_row40_col12,#T_d1e6f_row41_col8,#T_d1e6f_row41_col9{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_d1e6f_row1_col10,#T_d1e6f_row1_col11,#T_d1e6f_row49_col12{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_d1e6f_row2_col0,#T_d1e6f_row3_col0,#T_d1e6f_row3_col3,#T_d1e6f_row3_col4,#T_d1e6f_row3_col8,#T_d1e6f_row4_col0,#T_d1e6f_row5_col0,#T_d1e6f_row6_col0,#T_d1e6f_row7_col0,#T_d1e6f_row11_col9,#T_d1e6f_row13_col6,#T_d1e6f_row17_col9,#T_d1e6f_row20_col9,#T_d1e6f_row21_col3,#T_d1e6f_row21_col8,#T_d1e6f_row38_col9,#T_d1e6f_row42_col3,#T_d1e6f_row42_col8,#T_d1e6f_row43_col4,#T_d1e6f_row48_col4,#T_d1e6f_row49_col3,#T_d1e6f_row49_col8{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_d1e6f_row2_col2,#T_d1e6f_row5_col2,#T_d1e6f_row6_col2{
#             background-color:  #2a88bc;
#             color:  #000000;
#         }#T_d1e6f_row2_col4,#T_d1e6f_row6_col4,#T_d1e6f_row18_col10,#T_d1e6f_row18_col11{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_d1e6f_row3_col1,#T_d1e6f_row4_col1,#T_d1e6f_row4_col9,#T_d1e6f_row6_col6,#T_d1e6f_row9_col0,#T_d1e6f_row23_col2,#T_d1e6f_row26_col3,#T_d1e6f_row26_col8,#T_d1e6f_row39_col3,#T_d1e6f_row39_col8,#T_d1e6f_row42_col4,#T_d1e6f_row46_col6{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_d1e6f_row3_col2,#T_d1e6f_row4_col2,#T_d1e6f_row29_col2{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_d1e6f_row3_col7,#T_d1e6f_row18_col2{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_d1e6f_row4_col5,#T_d1e6f_row8_col5,#T_d1e6f_row15_col1,#T_d1e6f_row24_col5,#T_d1e6f_row38_col5{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_d1e6f_row4_col6,#T_d1e6f_row38_col12{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_d1e6f_row4_col7{
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }#T_d1e6f_row4_col12,#T_d1e6f_row18_col1,#T_d1e6f_row30_col4,#T_d1e6f_row37_col5,#T_d1e6f_row49_col5{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_d1e6f_row5_col4,#T_d1e6f_row10_col1,#T_d1e6f_row24_col9,#T_d1e6f_row35_col4{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_d1e6f_row5_col6,#T_d1e6f_row23_col1,#T_d1e6f_row34_col6{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_d1e6f_row5_col7,#T_d1e6f_row34_col7{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_d1e6f_row5_col9,#T_d1e6f_row9_col1,#T_d1e6f_row11_col6{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_d1e6f_row5_col12,#T_d1e6f_row8_col1,#T_d1e6f_row11_col12,#T_d1e6f_row12_col0,#T_d1e6f_row34_col12{
#             background-color:  #f2ecf5;
#             color:  #

# %%
dcoll.loc['hater']
# Out:
# place   kind
# before  counts       13.000000
#         dist         13.000000
#         bdist         3.533333
#         freq      99631.000000
#         pmi           0.878704
# after   counts       11.000000
#         dist        110.000000
#         bdist        11.538462
#         freq      99631.000000
#         pmi           0.734623
# score                 0.725929
# before  score        -0.036596
# after   score        -0.026728
# Name: hater, dtype: float64

# %%
dcoll[[("before", 'pmi'), ('before', 'counts'),('after','counts'),('after','pmi')]].sort_values(by = ('after', 'pmi'), ascending = False).head(20)
# Out:
# place              before             after
# kind                  pmi   counts   counts          pmi
# –             4502.544806  18675.0  19116.0  4571.098680
# karantene      953.856945   1398.0   1961.0  1335.415740
# 2021          1362.191090   1457.0    818.0   749.447260
# NYHETER       1250.587594    515.0    313.0   746.018128
# ahte           687.093169    511.0    418.0   554.944478
# smittevern     285.781044    301.0    569.0   542.417283
# viruset        171.572684    385.0   1076.0   485.232780
# leat           456.557960    570.0    582.0   462.326114
# munnbind       319.592702    244.0    340.0   444.417488
# FHI            424.117757    223.0    226.0   426.215773
# maid           398.082795    178.0    154.0   340.439195
# smittede       237.277287    407.0    542.0   315.044975
# hjemmekontor   174.921428    199.0    302.0   265.364836
# 2020           430.361706   3314.0   2013.0   256.577241
# 20.05            2.294681      1.0     93.0   231.631879
# lea            260.984297    909.0    745.0   211.203946
# Eydehavn         1.784560      2.0    213.0   206.847976
# testa          615.734862    742.0    254.0   204.519897
# FOTO           155.182581    727.0    938.0   199.502426
# Eides           63.530781     71.0    218.0   197.765129
