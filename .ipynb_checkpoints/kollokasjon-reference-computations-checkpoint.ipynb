# %% [markdown]
# # Code for collocations in newspapers

# %% [markdown]
# Some startup code, make sure to activate

# %%
import dhlab.module_update as mu
mu.update('dhlab_v2', silent = True)
import dhlab_v2 as d2

import pandas as pd

from random import sample

from util import sampling, sort, check_words, collocation, coll_dist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2f7c7bb5d27c> in <module>
#       7 from random import sample
#       8
# ----> 9 from util import sampling, sort, check_words, collocation, coll_dist
#
# ~\Documents\GitHub\Vaksine_og_forskning\util.py in <module>
#      24     return subcorpus
#      25
# ---> 26 def collocation(word, before = 20, after = 20, corpus = None, samples = 500000, totals = tot ):
#      27     """ Collocations from counts - no distance here"""
#      28     coll = d2.urn_collocation(urns = sampling(list(corpus.urn), samples), word = word, before = before, after = after)
#
# NameError: name 'tot' is not defined

# %%
import util

# %%
mu.css("css.css")

# %% [markdown]
# # Setting things up
# Set up the data for analysis, totals and a collocation function

# %%
tot = d2.totals(200000)

# %% [markdown]
# With collocations, the information association is computed using PMI (pointwise mutual information), with probabilites as proportions of frequency, it takes the form: $pmi(x,y) = \frac{p(x|y)}{p(x)} = \frac{p(y|x)}{p(y)}$. It is a probabilistic version of relevance. That $y$ is relevant for $x$ and vice versa. PMI is used instead of $\text{tf-idf}$ for computing associations between words.
#
# The PMI-values are computed on normalized frequencies, which means that the actual number can be interpreted as a disproportion number.

# %% [markdown]
# ## Build a corpus
#
# The target corpus consists of newspapers published in Norway between 2020 and 2021

# %%
corpus = d2.document_corpus(doctype = 'digavis', from_year = 2020, to_year = 2022, limit = 100000)

# %% [markdown]
# Check how many documents there are in the corpus

# %%
len(corpus)
# Out:
# 43490

# %%
import imp
imp.reload(util)
# Out:
# <module 'util' from 'C:\\Users\\larsj\\Documents\\GitHub\\Vaksine_og_forskning\\util.py'>

# %%
util.TITLES_NATIONAL
# Out:
# ['aftenposten',
#  'verdensgang',
#  'dagbladet',
#  'dagsavisen',
#  'dagensnaeringsliv',
#  'morgenbladet',
#  'klassekampen',
#  'finansavisen',
#  'vaartland',
#  'nationen',
#  'aftenpostenjunior']

# %%
subcorpus = util.make_subcorpus(util.TITLES_NATIONAL, corpus)

# %%
len(subcorpus)
# Out:
# 4180

# %% [markdown]
# def collocation(word, before = 20, after = 20, corpus = None, samples = 500000, totals = None ):
#     """ Collocations from counts - no distance here"""
#     coll = d2.urn_collocation(urns = sampling(list(corpus.urn), samples), word = word, before = before, after = after)
#     combo = pd.concat([coll.counts, totals.freq], axis = 1)
#     combo.freq = combo.freq.fillna(max(min(combo.freq), 1))
#     combo = combo.fillna(0)
#     coll['pmi'] = (combo.counts/combo.counts.sum())**1.02/(combo.freq/combo.freq.sum())
#     return coll

# %% [markdown]
# # Collocations
#
# Try out different words to get a feel of things

# %%
dcoll = coll_dist('vaksine', corpus = subcorpus, totals = tot, window = 20)

# %%
coll10 = collocation("vaksine", before = 10, after = 10, corpus = subcorpus, totals = tot)

# %%
coll10 = coll10[['counts', 'pmi']]

# %%
coll.sort_values(by = 'pmi', ascending = False).head(20)
# Out:
#                counts           pmi
# covid-19          212  20998.260045
# koronaviruset     153  15055.874676
# efektiv           113  11052.505609
# Pfizer             75   7275.841343
# coronaviruset      72   6979.107341
# AstraZenecas       71   6880.250449
# Pfizers            69   6682.620585
# korona             68   6583.848405
# ­                  68   6583.848405
# ●                  65   6287.707862
# Modernas           46   4419.098887
# –                 526   3922.090908
# Moderna            37   3539.048303
# pandemien          36   3441.511954
# AstraZeneca        31   2954.674604
# Covid-19           24   2275.811031
# FHI                37   2254.868556
# 2021.              23   2179.129923
# Zenecas            21   1986.023634
# →                  18   1697.065821

# %%
coll10.sort_values(by = 'pmi', ascending = False)
# Out:
#                   counts       pmi
# covid-19-medisin       5       inf
# KLÆBO                  1       inf
# Anisa                  1       inf
# KREVER                 1       inf
# Pharmaceutica          1       inf
# ...                  ...       ...
# in                     1  0.016054
# c                      1  0.013426
# <                      1  0.011325
# henne                  1  0.010665
# ^                      1  0.005486
#
# [13246 rows x 2 columns]

# %%
dcoll_lukte = coll_dist('lukte', corpus = subcorpus, totals = tot)

# %%
dcoll.sort_values(by = ('before', 'pmi'), ascending = False).head(50)
# Out:
# place           before                                 after          \
# kind            counts    dist     bdist          pmi counts    dist
# efektiv           96.0   159.0  1.826531  9359.503757   38.0   191.0
# Pfizer            82.0   457.0  5.678571  7969.412280   49.0   244.0
# AstraZenecas      70.0    99.0  1.652778  6781.662398    4.0    20.0
# Pfizers           67.0    97.0  1.695652  6485.335740   11.0    70.0
# ●                 52.0   277.0  5.500000  5007.945291   57.0   286.0
# covid-19          51.0   231.0  4.735849  4909.731528  201.0   548.0
# Modernas          49.0    76.0  1.882353  4713.420289    5.0    42.0
# ­                 45.0   159.0  3.808511  4321.285191   50.0   169.0
# Moderna           44.0   266.0  6.217391  4223.357986   32.0   172.0
# pandemien         42.0   305.0  7.386364  4027.638109   46.0   258.0
# –                434.0  2798.0  6.463303  3223.793048  639.0  3165.0
# AstraZeneca       32.0   195.0  6.323529  3052.032424   30.0   155.0
# ...

# %%
dcoll[dcoll[('before','counts')] > 10].sort_values(by = ('before', 'pmi'), ascending = False).head(50)
# Out:
# place                before                          after                     \
# kind                 counts    dist      bdist  pmi counts    dist      bdist
# AstraZenecas           72.0   125.0   2.229730  inf    8.0    82.0  12.200000
# 2021.                  33.0   322.0  10.342857  inf   48.0   483.0  10.460000
# smitteverntiltak       14.0   183.0  13.937500  inf   15.0   175.0  12.647059
# Nakstad                19.0   217.0  12.238095  inf   25.0   220.0   9.629630
# vaksinekandidater      12.0   179.0  15.642857  inf   14.0   187.0  14.187500
# AstraZeneca            50.0   486.0  10.115385  inf   53.0   529.0  10.345455
# KLASSEKAMPEN           19.0   173.0  10.142857  inf    4.0    39.0  13.166667
# CORONA-KRISEN          12.0   153.0  13.785714  inf    8.0    98.0  13.800000
# Biontech               21.0   195.0  10.217391  inf   23.0   188.0   9.120000
# Moderna                81.0   810.0  10.240964  inf   63.0   628.0  10.276923
# ...

# %%
dcoll.sort_values(by = ('before', 'counts'), ascending = False).head(50)
# Out:
# place    before                                   after                     \
# kind     counts     dist     bdist          pmi  counts     dist     bdist
# en       3135.0   6610.0  2.113484     4.424852   604.0   3677.0  6.100660
# .        2460.0  16029.0  6.518684     0.624010  4198.0  19618.0  4.675714
# å        1411.0   6618.0  4.697806     2.362341   686.0   4454.0  6.502907
# ,        1384.0   9319.0  6.738095     0.413049  2757.0  12894.0  4.680681
# at       1261.0   6956.0  5.523357     1.990352   745.0   4887.0  6.568942
# i        1129.0   7583.0  6.722370     0.699022  1437.0   7710.0  5.371786
# er       1119.0   7151.0  6.396967     1.294148  1722.0   8561.0  4.977378
# og       1078.0   6208.0  5.766667     0.582597  1140.0   6032.0  5.299475
# det      1011.0   6261.0  6.200395     1.147462   959.0   5791.0  6.046826
# av        946.0   4538.0  4.808017     1.111697   683.0   4142.0  6.075912
# ...

# %%
dcoll[dcoll[('before', 'pmi')]> 100].sort_values(by = ('before', 'counts'), ascending = False).head(50)
# Out:
# place                 before                                 after          \
# kind                  counts    dist     bdist          pmi counts    dist
# –                      434.0  2798.0  6.463303  3223.793048  639.0  3165.0
# vaksine                132.0   904.0  6.895522  1178.355210  132.0   904.0
# efektiv                 96.0   159.0  1.826531  9359.503757   38.0   191.0
# doser                   89.0   366.0  4.241758   265.650843   44.0   280.0
# Pfizer                  82.0   457.0  5.678571  7969.412280   49.0   244.0
# NTB                     70.0   384.0  5.611111   262.652207   51.0   325.0
# AstraZenecas            70.0    99.0  1.652778  6781.662398    4.0    20.0
# 2021                    68.0   454.0  6.771429  1986.203730   61.0   382.0
# Pfizers                 67.0    97.0  1.695652  6485.335740   11.0    70.0
# vaksinen                64.0   473.0  7.469697  1433.836565   98.0   691.0
# ...

# %%
dcoll_lukte[dcoll_lukte[('before', 'counts')] > 5].sort_values(by = ('before', 'pmi'), ascending = False).head(50)
# Out:
# place     before                                after                    \
# kind      counts   dist     bdist          pmi counts   dist      bdist
# luktesans    6.0   56.0  9.500000  2725.559249    1.0    5.0   8.333333
# –           16.0   98.0  6.555556  2174.791271   30.0  158.0   5.562500
# Hunder       6.0   16.0  4.500000  1420.167705    4.0   30.0   8.333333
# Spot         6.0   28.0  6.000000  1234.662838    NaN    NaN        NaN
# lukte       10.0   64.0  7.000000   709.018631   10.0   64.0   7.000000
# hundene     10.0   47.0  5.583333   457.529531    NaN    NaN        NaN
# hunder      17.0   57.0  4.052632   444.129132    NaN    NaN        NaN
# smake        6.0   22.0  5.250000   262.395638   16.0   57.0   4.277778
# fi           6.0   30.0  6.250000    87.652775    2.0    6.0   6.500000
# hunden       6.0   22.0  5.250000    74.054428    2.0   20.0  10.000000
# begynner    18.0   38.0  2.900000    60.086598    NaN    NaN        NaN
# ...

# %%
c = ["URN:NBN:no-nb_digitidsskrift_2019012281068_001"]

# %%
conc = d2.concordance(urns = c, words="kvinde", limit = 10000)
len(conc)
# Out:
# 54

# %%
from dhlab.nbtext import pure_urn

# %%
x = nb.pure_urn("""
Nasjonalbiblioteket
Logg inn
Søk i nettbiblioteket:
Søk i nettbiblioteket
Søk
Nasjonalbiblioteket
Alt
Bøker
Aviser
Bilder
Tidsskrift
Kart
Brev og manuskripter
Musikk
Noter
Musikkmanuskripter
Plakater
Tittel: nylænde
clear
SØK ETTER TIDSSKRIFTNAVN
nylænde
Søk etter tidsskriftnavn
SØK ETTER TEMA/EMNE
Søk etter tema/emne
DATO

Fra dato:
Fra dato
dd.mm.åååå

Til dato:
Til dato
dd.mm.åååå
Chart
Bar chart with 9 bars.
The chart has 1 X axis displaying categories.
The chart has 1 Y axis displaying values. Range: 0 to 6.
End of interactive chart.
BIBLIOGRAFI/SAMLING
Alle	
 Bibliografi/samling

41 Treff i tidsskrift
Sortering:
(api 0 ms)

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 
001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
CCBYNCND
legaldeposit
Tidsskrift998340832054702202
jp2

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 1892 Vol. 6
Foreningen
1892
Tilgang for alle
(api)
id: 92f5294adb99764c415b0acb79868bac
urn: URN:NBN:no-nb_digitidsskrift_2019011881236_001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
CCBYNCND
legaldeposit
Tidsskrift998340832054702202
jp2

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 1897 Vol. 11
Foreningen
1897
Tilgang for alle
(api)
id: 4fc2c785ee98e1f810213b07378d281f
urn: URN:NBN:no-nb_digitidsskrift_2019012281038_001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
CCBYNCND
legaldeposit
Tidsskrift998340832054702202
jp2

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 1904 Vol. 18
Foreningen
1904
Tilgang for alle
(api)
id: e90a3ab2ee252be41c8661c20ed02242
urn: URN:NBN:no-nb_digitidsskrift_2019011881248_001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
CCBYNCND
legaldeposit
Tidsskrift998340832054702202
jp2

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 1887 Vol. 1
Foreningen
1887
Tilgang for alle
(api)
id: c07c4c1b401e43c33e733aded4046b2a
urn: URN:NBN:no-nb_digitidsskrift_2018091981002_001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
legaldeposit
Tidsskrift998340832054702202
jp2
publicdomain

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 1907 Vol. 21
Foreningen
1907
Tilgang for alle
(api)
id: 5e4d636e1c6c9ad2ba574b3d8d0d349c
urn: URN:NBN:no-nb_digitidsskrift_2019012281072_001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
CCBYNCND
legaldeposit
Tidsskrift998340832054702202
jp2

Nylænde (trykt utg.) : tidsskrift udgivet af Norsk kvindesagsforening. 1916 Vol. 30
Foreningen
1916
Tilgang for alle
(api)
id: ecff00e544bafc67d0c737995c1804e8
urn: URN:NBN:no-nb_digitidsskrift_2019012281044_001
isDigital: true
viewability: ALL
allowedFrom: EVERYWHERE
contentClasses:
public
CCBYNCND
legaldeposit
Tidsskrift998340832054702202
jp2
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-45271059d404> in <module>
# ----> 1 x = nb.pure_urn("""
#       2 Nasjonalbiblioteket
#       3 Logg inn
#       4 Søk i nettbiblioteket:
#       5 Søk i nettbiblioteket
#
# NameError: name 'nb' is not defined

# %%
conc.sample(min(len(conc), 10)).style
# Out:
# <style  type="text/css" >
# </style><table id="T_6ac3c711_1c99_11ec_b2f4_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ac3c711_1c99_11ec_b2f4_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >42</th>
#                         <td id="T_6ac3c711_1c99_11ec_b2f4_a0a4c554f2a3row0_col0" class="data row0 col0" >300033066</td>
#                         <td id="T_6ac3c711_1c99_11ec_b2f4_a0a4c554f2a3row0_col1" class="data row0 col1" >URN:NBN:no-nb_digitidsskrift_2019012281068_001</td>
# ...

# %%
cc = d2.concordance_counts(urns = list(subcorpus.urn), words="korona", limit = 5000)

# %%
cc.loc['hunder']
# Out:
# freq    25
# Name: hunder, dtype: int64

# %%
cc['pmi'] = (cc.freq/cc.freq.sum())/(tot.freq/tot.freq.sum())

# %%
cc_relevance = cc[cc.pmi > 20].sort_values(by = 'freq', ascending = False)

# %%
cc.loc['drittlei']
# Out:
# freq     7.000000
# pmi     44.232848
# Name: drittlei, dtype: float64

# %%
d2.concordance(urns = list(subcorpus.urn), words = "drittlei korona").style
# Out:
# <style  type="text/css" >
# </style><table id="T_dab916f5_1bbd_11ec_a42d_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >docid</th>        <th class="col_heading level0 col1" >urn</th>        <th class="col_heading level0 col2" >conc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dab916f5_1bbd_11ec_a42d_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dab916f5_1bbd_11ec_a42d_a0a4c554f2a3row0_col0" class="data row0 col0" >203339616</td>
#                         <td id="T_dab916f5_1bbd_11ec_a42d_a0a4c554f2a3row0_col1" class="data row0 col1" >URN:NBN:no-nb_digavis_nationen_null_null_20210520_0_113_1</td>
# ...
